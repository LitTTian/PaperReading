# %% [markdown]
# ## 摘要 Abstract

# %% [markdown]
# <!-- 多模态大语言模型（MLLMs）经常表现出幻觉现象，但其根本原因仍不清楚。在本文中，我们进行了实证分析，发现尽管 MLLMs 在最终输出中错误地生成了物体，但它们实际上能够识别前几层的视觉物体。我们推测这可能是由于语言模型的强知识先验抑制了视觉信息，导致幻觉。受此启发，我们提出了一种针对 MLLMs 的新型动态校正解码方法（DeCo），该方法自适应地选择适当的前几层，并将知识按比例整合到最终层以调整输出 logits。请注意，DeCo 是模型无关的，可以与各种经典解码策略无缝集成，并应用于不同的 MLLMs。我们在广泛使用的基准测试上评估了 DeCo，证明与基线相比，它可以大幅降低幻觉率，突显了其缓解幻觉的潜力 1 。 -->
#
# - 幻觉原因未知
# - 在前几层能识别物体
# - 可能是语言模型的强知识先验抑制了视觉信息
# - 提出动态校正解码方法 DeCo

# %% [markdown]
# ## 提出方法：基于前层知识的动态校正解码 Proposed Approach: Dynamic Correction Decoding with Preceding-Layer Knowledge
