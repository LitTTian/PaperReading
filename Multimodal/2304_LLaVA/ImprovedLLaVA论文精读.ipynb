# %% [markdown]
# - 主要改进：
#     - 视觉编码器：clip-L/14(224px) --> CLIP-ViT-L/14@336px
#     - 更高的分辨率输入：224 --> 336
#     - 改进投影层: 线性层 --> 两层MLP (文中尝试了各种复杂的设计：transformer...)
#     - LLM: Vicuna-7B --> Vicuna v1.5 - 13B
