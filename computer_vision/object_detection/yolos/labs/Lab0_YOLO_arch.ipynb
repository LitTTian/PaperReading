# %%
import torch
from utils.yolov1 import YOLOv1
from ultralytics import YOLO
# from torchsummary import summary
from torchinfo import summary

# %% [markdown]
# ## YOLOv1

# %%
# 初始化YOLOv1模型（默认20类，对应VOC数据集）
yolov1 = YOLOv1(num_classes=20, num_bboxes=2)

print(yolov1)
summary(yolov1, (3, 448, 448))
# Out:
# YOLOv1(
#   (backbone): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.1)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.1)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.1)
#     (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.1)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): LeakyReLU(negative_slope=0.1)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %% [markdown]
# ## YOLOv2

# %% [markdown]
# |                | YOLO  |      |      |      |      |      |      |      | YOLOv2 |
# |----------------|-------|------|------|------|------|------|------|------|--------|
# | batch norm?    |       | ✓    | ✓    | ✓    | ✓    | ✓    | ✓    | ✓    | ✓      |
# | hi-res classifier? |    |      | ✓    | ✓    | ✓    | ✓    | ✓    | ✓    | ✓      |
# | convolutional? |       |      |      | ✓    | ✓    | ✓    | ✓    | ✓    | ✓      |
# | anchor boxes?  |       |      |      | ✓    | ✓    |      |      |      |        |
# | new network?   |       |      |      |      | ✓    | ✓    | ✓    | ✓    | ✓      |
# | dimension priors? |    |      |      |      |      | ✓    | ✓    | ✓    | ✓      |
# | location prediction? |  |      |      |      |      | ✓    | ✓    | ✓    | ✓      |
# | passthrough?   |       |      |      |      |      |      | ✓    | ✓    | ✓      |
# | multi-scale?   |       |      |      |      |      |      |      | ✓    | ✓      |
# | hi-res detector? |     |      |      |      |      |      |      |      | ✓      |
# |----------------|-------|------|------|------|------|------|------|------|--------|
# | VOC2007 mAP    | 63.4  | 65.8 | 69.5 | 69.2 | 69.6 | 74.4 | 75.4 | 76.8 | **78.6** |

# %% [markdown]
# - 分类任务：
#
# | Type          | Filters | Size/Stride       | Output       |
# |---------------|---------|-------------------|--------------|
# | Convolutional | 32      | $3 \times 3$      | $224 \times 224$ |
# | Maxpool       | -       | $2 \times 2 / 2$  | $112 \times 112$ |
# | Convolutional | 64      | $3 \times 3$      | $112 \times 112$ |
# | Maxpool       | -       | $2 \times 2 / 2$  | $56 \times 56$   |
# | Convolutional | 128     | $3 \times 3$      | $56 \times 56$   |
# | Convolutional | 64      | $1 \times 1$      | $56 \times 56$   |
# | Convolutional | 128     | $3 \times 3$      | $56 \times 56$   |
# | Maxpool       | -       | $2 \times 2 / 2$  | $28 \times 28$   |
# | Convolutional | 256     | $3 \times 3$      | $28 \times 28$   |
# | Convolutional | 128     | $1 \times 1$      | $28 \times 28$   |
# | Convolutional | 256     | $3 \times 3$      | $28 \times 28$   |
# | Maxpool       | -       | $2 \times 2 / 2$  | $14 \times 14$   |
# | Convolutional | 512     | $3 \times 3$      | $14 \times 14$   |
# | Convolutional | 256     | $1 \times 1$      | $14 \times 14$   |
# | Convolutional | 512     | $3 \times 3$      | $14 \times 14$   |
# | Convolutional | 256     | $1 \times 1$      | $14 \times 14$   |
# | Convolutional | 512     | $3 \times 3$      | $14 \times 14$   |
# | Maxpool       | -       | $2 \times 2 / 2$  | $7 \times 7$     |
# | Convolutional | 1024    | $3 \times 3$      | $7 \times 7$     |
# | Convolutional | 512     | $1 \times 1$      | $7 \times 7$     |
# | Convolutional | 1024    | $3 \times 3$      | $7 \times 7$     |
# | Convolutional | 512     | $1 \times 1$      | $7 \times 7$     |
# | Convolutional | 1024    | $3 \times 3$      | $7 \times 7$     |
# |---------------|---------|-------------------|--------------|
# | Convolutional | 1000    | $1 \times 1$      | $7 \times 7$     |
# | Avgpool       | -       | Global            | $1000$       |
# | Softmax       | -       | -                 | -            |

# %% [markdown]
# - 目标检测任务
#
# <!-- | Type          | Filters | Size/Stride       | Output       | Note         |
# |---------------|---------|-------------------|--------------| -------------|
# | Input         | -       | -                 | $416 \times 416 \times 3$ |
# | Convolutional | 32      | $3 \times 3$      | $416 \times 416 \times 32$ |
# | Maxpool       | -       | $2 \times 2 / 2$  | $208 \times 208 \times 32$ |
# | Convolutional | 64      | $3 \times 3$      | $208 \times 208 \times 64$ |
# | Maxpool       | -       | $2 \times 2 / 2$  | $104 \times 104 \times 64$   |
# | Convolutional | 128     | $3 \times 3$      | $104 \times 104 \times 128$   |
# | Convolutional | 64      | $1 \times 1$      | $104 \times 104 \times 64$   |
# | Convolutional | 128     | $3 \times 3$      | $104 \times 104 \times 128$   |
# | Maxpool       | -       | $2 \times 2 / 2$  | $52 \times 52 \times 128$   |
# | Convolutional | 256     | $3 \times 3$      | $52 \times 52 \times 256$   |
# | Convolutional | 128     | $1 \times 1$      | $52 \times 52 \times 128$   |
# | Convolutional | 256     | $3 \times 3$      | $52 \times 52 \times 256$   |
# | Maxpool       | -       | $2 \times 2 / 2$  | $26 \times 26 \times 256$   |
# | Convolutional | 512     | $3 \times 3$      | $26 \times 26 \times 512$   |
# | Convolutional | 256     | $1 \times 1$      | $26 \times 26 \times 256$   |
# | Convolutional | 512     | $3 \times 3$      | $26 \times 26 \times 512$   |
# | Convolutional | 256     | $1 \times 1$      | $26 \times 26 \times 256$   |
# | Convolutional | 512     | $3 \times 3$      | $26 \times 26 \times 512$   |  Passthrough的输入(最后一次pool之前) |
# | Maxpool       | -       | $2 \times 2 / 2$  | $13 \times 13 \times 512$     |
# | Convolutional | 1024    | $3 \times 3$      | $13 \times 13 \times 1024$     |
# | Convolutional | 512     | $1 \times 1$      | $13 \times 13 \times 512$     |
# | Convolutional | 1024    | $3 \times 3$      | $13 \times 13 \times 1024$     |
# | Convolutional | 512     | $1 \times 1$      | $13 \times 13 \times 512$     |
# | Convolutional | 1024    | $3 \times 3$      | $13 \times 13 \times 1024$     |
# |---------------|---------|-------------------|--------------| ------------- |
# | Convolutional | 1024     | $3 \times 3$      | $13 \times 13 \times 1024$     |
# | Convolutional | 1024     | $3 \times 3$      | $13 \times 13 \times 1024$     |
# | Convolutional | 1024     | $3 \times 3$      | $13 \times 13 \times 1024$     |
# |---------------|---------|-------------------|--------------| ------------- |
# | Detection     |         |                   |              |              |
# | Route       | -       | -                 | $26 \times 26 \times 512$   | Passthrough层 |
# | Convolutional | 64      | $1 \times 1$      | $26 \times 26 \times 64$     |               |
# | Reorg        | -       | $/2$      | $13 \times 13 \times 256$     | 四个拼在一起        |
# |---------------|---------|-------------------|--------------| ------------- |
# | Route       | -       | -                 | $13 \times 13 \times 256 + 1024$   | 拼接         |
# | Convolutional | 1024    | $3 \times 3$      | $13 \times 13 \times 1024$     |
# | Convolutional | $B \times (5 + C)$ | $1 \times 1$ | $13 \times 13 \times (B \times (5 + C))$ | -->
#
# ```
#  layer    type   filters     size / stride             input            output
# ------------------------------------------------------------------------------
#           conv        32    3 x 3 / 1       416 x 416 x    3  416 x 416 x   32
#      1     max              2 x 2 / 2       416 x 416 x   32  208 x 208 x   32
#      2    conv        64    3 x 3 / 1       208 x 208 x   32  208 x 208 x   64
#      3     max              2 x 2 / 2       208 x 208 x   64  104 x 104 x   64
#      4    conv       128    3 x 3 / 1       104 x 104 x   64  104 x 104 x  128
#      5    conv        64    1 x 1 / 1       104 x 104 x  128  104 x 104 x   64
#      6    conv       128    3 x 3 / 1       104 x 104 x   64  104 x 104 x  128
#      7     max              2 x 2 / 2       104 x 104 x  128   52 x  52 x  128
#      8    conv       256    3 x 3 / 1        52 x  52 x  128   52 x  52 x  256
#      9    conv       128    1 x 1 / 1        52 x  52 x  256   52 x  52 x  128
#     10    conv       256    3 x 3 / 1        52 x  52 x  128   52 x  52 x  256
#     11     max              2 x 2 / 2        52 x  52 x  256   26 x  26 x  256
#     12    conv       512    3 x 3 / 1        26 x  26 x  256   26 x  26 x  512
#     13    conv       256    1 x 1 / 1        26 x  26 x  512   26 x  26 x  256
#     14    conv       512    3 x 3 / 1        26 x  26 x  256   26 x  26 x  512
#     15    conv       256    1 x 1 / 1        26 x  26 x  512   26 x  26 x  256
#     16    conv       512    3 x 3 / 1        26 x  26 x  256   26 x  26 x  512
#     17     max              2 x 2 / 2        26 x  26 x  512   13 x  13 x  512
#     18    conv      1024    3 x 3 / 1        13 x  13 x  512   13 x  13 x 1024
#     19    conv       512    1 x 1 / 1        13 x  13 x 1024   13 x  13 x  512
#     20    conv      1024    3 x 3 / 1        13 x  13 x  512   13 x  13 x 1024
#     21    conv       512    1 x 1 / 1        13 x  13 x 1024   13 x  13 x  512
#     22    conv      1024    3 x 3 / 1        13 x  13 x  512   13 x  13 x 1024
#     23    conv      1024    3 x 3 / 1        13 x  13 x 1024   13 x  13 x 1024
#     24    conv      1024    3 x 3 / 1        13 x  13 x 1024   13 x  13 x 1024
#     25   route        16
#     26    conv        64    1 x 1 / 1        26 x  26 x  512   26 x  26 x   64
#     27   reorg                    / 2        26 x  26 x   64   13 x  13 x  256
#     28   route     27 24
#     29    conv      1024    3 x 3 / 1        13 x  13 x 1280   13 x  13 x 1024
#     30    conv       125    1 x 1 / 1        13 x  13 x 1024   13 x  13 x  125
# ```

# %%
# 1. 存储网络结构数据（保持不变）
network_layers = [
    {"layer": 0, "type": "conv", "filters": 32, "size_stride": "3 x 3 / 1", "input": "416 x 416 x 3", "output": "416 x 416 x 32"},
    {"layer": 1, "type": "max", "filters": " ", "size_stride": "2 x 2 / 2", "input": "416 x 416 x 32", "output": "208 x 208 x 32"},
    {"layer": 2, "type": "conv", "filters": 64, "size_stride": "3 x 3 / 1", "input": "208 x 208 x 32", "output": "208 x 208 x 64"},
    {"layer": 3, "type": "max", "filters": " ", "size_stride": "2 x 2 / 2", "input": "208 x 208 x 64", "output": "104 x 104 x 64"},
    {"layer": 4, "type": "conv", "filters": 128, "size_stride": "3 x 3 / 1", "input": "104 x 104 x 64", "output": "104 x 104 x 128"},
    {"layer": 5, "type": "conv", "filters": 64, "size_stride": "1 x 1 / 1", "input": "104 x 104 x 128", "output": "104 x 104 x 64"},
    {"layer": 6, "type": "conv", "filters": 128, "size_stride": "3 x 3 / 1", "input": "104 x 104 x 64", "output": "104 x 104 x 128"},
    {"layer": 7, "type": "max", "filters": " ", "size_stride": "2 x 2 / 2", "input": "104 x 104 x 128", "output": "52 x 52 x 128"},
    {"layer": 8, "type": "conv", "filters": 256, "size_stride": "3 x 3 / 1", "input": "52 x 52 x 128", "output": "52 x 52 x 256"},
    {"layer": 9, "type": "conv", "filters": 128, "size_stride": "1 x 1 / 1", "input": "52 x 52 x 256", "output": "52 x 52 x 128"},
    {"layer": 10, "type": "conv", "filters": 256, "size_stride": "3 x 3 / 1", "input": "52 x 52 x 128", "output": "52 x 52 x 256"},
    {"layer": 11, "type": "max", "filters": " ", "size_stride": "2 x 2 / 2", "input": "52 x 52 x 256", "output": "26 x 26 x 256"},
    {"layer": 12, "type": "conv", "filters": 512, "size_stride": "3 x 3 / 1", "input": "26 x 26 x 256", "output": "26 x 26 x 512"},
    {"layer": 13, "type": "conv", "filters": 256, "size_stride": "1 x 1 / 1", "input": "26 x 26 x 512", "output": "26 x 26 x 256"},
    {"layer": 14, "type": "conv", "filters": 512, "size_stride": "3 x 3 / 1", "input": "26 x 26 x 256", "output": "26 x 26 x 512"},
    {"layer": 15, "type": "conv", "filters": 256, "size_stride": "1 x 1 / 1", "input": "26 x 26 x 512", "output": "26 x 26 x 256"},
    {"layer": 16, "type": "conv", "filters": 512, "size_stride": "3 x 3 / 1", "input": "26 x 26 x 256", "output": "26 x 26 x 512"},
    {"layer": 17, "type": "max", "filters": " ", "size_stride": "2 x 2 / 2", "input": "26 x 26 x 512", "output": "13 x 13 x 512"},
    {"layer": 18, "type": "conv", "filters": 1024, "size_stride": "3 x 3 / 1", "input": "13 x 13 x 512", "output": "13 x 13 x 1024"},
    {"layer": 19, "type": "conv", "filters": 512, "size_stride": "1 x 1 / 1", "input": "13 x 13 x 1024", "output": "13 x 13 x 512"},
    {"layer": 20, "type": "conv", "filters": 1024, "size_stride": "3 x 3 / 1", "input": "13 x 13 x 512", "output": "13 x 13 x 1024"},
    {"layer": 21, "type": "conv", "filters": 512, "size_stride": "1 x 1 / 1", "input": "13 x 13 x 1024", "output": "13 x 13 x 512"},
    {"layer": 22, "type": "conv", "filters": 1024, "size_stride": "3 x 3 / 1", "input": "13 x 13 x 512", "output": "13 x 13 x 1024"},
    {"layer": 23, "type": "conv", "filters": 1024, "size_stride": "3 x 3 / 1", "input": "13 x 13 x 1024", "output": "13 x 13 x 1024"},
    {"layer": 24, "type": "conv", "filters": 1024, "size_stride": "3 x 3 / 1", "input": "13 x 13 x 1024", "output": "13 x 13 x 1024"},
    {"layer": 25, "type": "route", "filters": "16"},
    {"layer": 26, "type": "conv", "filters": 64, "size_stride": "1 x 1 / 1", "input": "26 x 26 x 512", "output": "26 x 26 x 64"},
    {"layer": 27, "type": "reorg", "filters": " ", "size_stride": "/ 2", "input": "26 x 26 x 64", "output": "13 x 13 x 256"},
    {"layer": 28, "type": "route", "filters": "27 24"},
    {"layer": 29, "type": "conv", "filters": 1024, "size_stride": "3 x 3 / 1", "input": "13 x 13 x 1280", "output": "13 x 13 x 1024"},
    {"layer": 30, "type": "conv", "filters": 125, "size_stride": "1 x 1 / 1", "input": "13 x 13 x 1024", "output": "13 x 13 x 125"},
]

# 2. 修复后的格式化打印函数
def print_network_table(layers):
    # 定义列宽（精准匹配内容长度，避免挤压）
    col_widths = {
        "layer": 6,    # 数字0-30，右对齐
        "type": 8,     # conv/max/route/reorg，右对齐
        "filters": 10,  # 数字/空格/16/27 24，右对齐
        "size_stride": 18, # 3 x 3 / 1 这类内容，/对齐，x对齐
        "input": 18,   # 416 x 416 x 3 这类内容，x对齐
        "output": 18   # 416 x 416 x 32 这类内容，x对齐
    }
    
    # 打印表头（表头保持左对齐，数据右对齐）
    layer_col = 'layer'.rjust(col_widths['layer'])
    type_col = 'type'.rjust(col_widths['type'])
    filters_col = 'filters'.rjust(col_widths['filters'])
    size_stride_col = "size / stride".rjust(col_widths['size_stride'])
    input_col = 'input'.rjust(col_widths['input'])
    output_col = 'output'.rjust(col_widths['output'])

    header = (
        f"{layer_col}"
        f"{type_col}"
        f"{filters_col}"
        f"{size_stride_col}"
        f"{input_col}"
        f"{output_col}"
    )
    print(header)
    # 打印分隔线
    print("-" * sum(col_widths.values()))
    
    def format_col(text, col_name):
        """按列类型格式化，保证符号顺序和对齐"""
        if not text:
            return " " * col_widths[col_name]
        
        # 基础列：纯右对齐（layer/type/filters）
        if col_name in ["layer", "type", "filters"]:
            return str(text).rjust(col_widths[col_name])
        
        # 特殊列：size_stride/input/output（保证符号顺序，仅对齐位置）
        width = col_widths[col_name]
        
        # 处理 size_stride 列：固定 / 在第8位（从左数），x 位置不变
        if col_name == "size_stride":
            if "/" in text:
                # 拆分 / 前后内容，固定 / 的位置
                left, right = text.split("/", 1)
                left = left.strip().rjust(6)  # 左部分右对齐占6位
                right = right.strip().ljust(6) # 右部分左对齐占3位
                return f"{left} / {right}".rjust(width)[:width]
            else:
                return text.rjust(width)
        
        # 处理 input/output 列：固定 x 的位置（第4位和第9位）
        if col_name in ["input", "output"]:
            parts = text.split("x")
            if len(parts) == 3:
                # 格式：数字 x 数字 x 数字
                p1 = parts[0].strip().rjust(3)  # 第一个数字右对齐占3位
                p2 = parts[1].strip().rjust(3)  # 第二个数字右对齐占3位
                p3 = parts[2].strip().rjust(4)  # 第三个数字右对齐占3位
                return f"{p1} x {p2} x {p3}".rjust(width)
            else:
                return text.rjust(width)
        
        return str(text).rjust(width)
    
    # 逐行打印数据
    for layer in layers:
        # 提取每列内容，无则为空字符串
        layer_val = layer.get("layer", "")
        type_val = layer.get("type", "")
        filters_val = layer.get("filters", "")
        size_stride_val = layer.get("size_stride", "")
        input_val = layer.get("input", "")
        output_val = layer.get("output", "")
        
        # 格式化每一列
        layer_col = format_col(layer_val, "layer")
        type_col = format_col(type_val, "type")
        filters_col = format_col(filters_val, "filters")
        size_stride_col = format_col(size_stride_val, "size_stride")
        input_col = format_col(input_val, "input")
        output_col = format_col(output_val, "output")
        
        # 拼接并打印行
        row = (
            f"{layer_col}"
            f"{type_col}"
            f"{filters_col}"
            f"{size_stride_col}"
            f"{input_col}"
            f"{output_col}"
        )
        print(row)

# 3. 调用函数
if __name__ == "__main__":
    print("=== YOLO网络结构表（符号顺序正确+对齐）===")
    print_network_table(network_layers)
# Out:
# === YOLO网络结构表（符号顺序正确+对齐）===
#  layer    type   filters     size / stride             input            output
# ------------------------------------------------------------------------------
#           conv        32    3 x 3 / 1       416 x 416 x    3  416 x 416 x   32
#      1     max              2 x 2 / 2       416 x 416 x   32  208 x 208 x   32
#      2    conv        64    3 x 3 / 1       208 x 208 x   32  208 x 208 x   64
#      3     max              2 x 2 / 2       208 x 208 x   64  104 x 104 x   64
#      4    conv       128    3 x 3 / 1       104 x 104 x   64  104 x 104 x  128
#      5    conv        64    1 x 1 / 1       104 x 104 x  128  104 x 104 x   64
#      6    conv       128    3 x 3 / 1       104 x 104 x   64  104 x 104 x  128
#      7     max              2 x 2 / 2       104 x 104 x  128   52 x  52 x  128
#      8    conv       256    3 x 3 / 1        52 x  52 x  128   52 x  52 x  256
# ...

# %% [markdown]
# - YOLOv2改进(相对于YOLOv1)：
#   - 骨干网络：使用更深的网络（Darknet-19），使用BN层
#   - 特征融合：Passthrough层简单融合
#   - k-means聚类5个锚框
#   - 检测尺度：单尺度(448x448) + 多尺度训练
#   - 分类：Softmax 单标签
#   - 小目标检测：高分辨率训练 + Passthrough层
#   - 精读/速度：召回率提升，速度提升

# %% [markdown]
# ## YOLOv3

# %% [markdown]
# - YOLOv3改进(相对于YOLOv2)：
#   - 骨干网络：使用更深的网络（Darknet-53），使用残差连接
#   - 特征融合：FPN多尺度特征融合（3尺度输出）
#   - k-means聚类9个锚框
#   - 检测尺度：三尺度(320x320, 416x416, 608x608) + 多尺度训练
#   - 分类：独立的Logistic回归 多标签
#   - 小目标检测：FPN多尺度检测
#   - 精读/速度：mAP提升，速度略有下降

# %%
import torch
from ultralytics import YOLO
from torchinfo import summary

yolov3 = YOLO('models/yolov3u.pt')  # 加载预训练的YOLOv3模型
print(yolov3)
# summary(yolov3.model, (3, 448, 448))
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# ## YOLOv5

# %%
# yolov5nu, yolov5su, yolov5mu, yolov5lu, yolov5xu, yolov5n6u, yolov5s6u, yolov5m6u, yolov5l6u, yolov5x6u
yolov5 = YOLO("models/yolov5nu")
print(yolov5)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3(
#         (cv1): Conv(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## YOLOv8

# %%
yolov8 = YOLO("models/yolov8n.pt")
print(yolov8)
# save_label(yolov8, "./labs/assets/dog_bike_car.jpg", save_label_dir="./labs/assets/labels")
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ### C2f层

# %% [markdown]
# - Yolov8中的C2f层是CSP Bottleneck的加速版本，使用了更高效的通道分割和融合方式。
# - 输入通过cv1卷积层后，在通道维度上被均分为两部分。
# - 第一部分直接保留，第二部分依次通过n个Bottleneck块进行处理。
# - 最后将所有部分在通道维度上拼接，并通过cv2卷积层输出结果。
# - 下面是C2f层的实现代码：

# %%
import torch
import torch.nn as nn
from ultralytics.nn.modules import Conv, Bottleneck
class C2f(nn.Module):
    """Faster Implementation of CSP Bottleneck with 2 convolutions."""

    def __init__(self, c1: int, c2: int, n: int = 1, shortcut: bool = False, g: int = 1, e: float = 0.5):
        """Initialize a CSP bottleneck with 2 convolutions.

        Args:
            c1 (int): 输入通道数
            c2 (int): 输出通道数
            n (int): Bottleneck块的数量。
            shortcut (bool): 是否使用快捷连接。
            g (int): 卷积的组数。
            e (float): 扩展比例。
        """
        super().__init__()
        self.c = int(c2 * e)  # 隐藏通道数，默认为输出通道的50%
        self.cv1 = Conv(c1, 2 * self.c, 1, 1)
        self.cv2 = Conv((2 + n) * self.c, c2, 1)  # optional act=FReLU(c2)
        self.m = nn.ModuleList(Bottleneck(self.c, self.c, shortcut, g, k=((3, 3), (3, 3)), e=1.0) for _ in range(n))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """C2f的前向传播"""
        y = list(self.cv1(x).chunk(2, 1))  # cv1的输出在第1维度(通道)切分为两部分
        y.extend(m(y[-1]) for m in self.m)  # 对最后一部分进行n个Bottleneck块的处理
        # y = [a, b, y1, ..., yn]
        return self.cv2(torch.cat(y, 1))  # 在第1个维度上拼接所有部分后通过cv2

    def forward_split(self, x: torch.Tensor) -> torch.Tensor:
        """使用split()代替chunk()的前向传播"""
        y = self.cv1(x).split((self.c, self.c), 1)
        y = [y[0], y[1]]
        y.extend(m(y[-1]) for m in self.m)
        return self.cv2(torch.cat(y, 1))
