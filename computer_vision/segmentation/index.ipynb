# %% [markdown]
# # 目录
#
# __Unet__
# - [U-Net](./2015_unet/papers/1505.04597v1[U-Net-%20Convolutional%20Networks%20for%20Biomedical%20Image%20Segmentation].pdf)
#
#
# __DeepLab__
#
# - [DeepLabV1](./2016_deeplab/papers/1412.7062v4[Semantic%20Image%20Segmentation%20with%20Deep%20Convolutional%20Nets%20and%20Fully%20Connected%20CRFs].pdf)
# - [DeepLabV2](./2016_deeplab/papers/1606.00915v2[DeepLab-%20Semantic%20Image%20Segmentation%20with%20Deep%20Convolutional%20Nets,%20Atrous%20Convolution,%20and%20Fully%20Connected%20CRFs].pdf)
# - [DeepLabV3](./2016_deeplab/papers/1706.05587v3[Rethinking%20Atrous%20Convolution%20for%20Semantic%20Image%20Segmentation].pdf)
#
#
# __SAM__
# - [SAM](./2023_sam/papers/2304.02643v1[Segment%20Anything].pdf)
