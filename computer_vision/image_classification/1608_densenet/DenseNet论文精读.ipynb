# %% [markdown]
# <div style="background-color: white; width: 80%; margin:auto; text-align: center; ">
#     <image src="./assets/denseBlock_white_bg.png" />
#     <span style="font-size: 12px; color: gray;">图 1. 一个增长率为k=4的5层密集块。每一层都使用所有先前特征图作为输入。</span>
# </div>
