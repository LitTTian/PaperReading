# %%
# 21_StableDiffusion1.5\labs\models\rdm\latent_diffusion
from models.rdm.latent_diffusion.scripts.knn2img import get_model
from torchinfo import summary
from PIL import Image

# %%
import torch
print(f"PyTorch 版本: {torch.__version__}")
print(f"CUDA 是否可用: {torch.cuda.is_available()}")
print(f"GPU 设备名称: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else '无'}")
print(f"GPU 数量: {torch.cuda.device_count()}")
# Out:
# PyTorch 版本: 2.4.1+cu118
# CUDA 是否可用: True
# GPU 设备名称: NVIDIA GeForce RTX 4090
# GPU 数量: 1

# %%
# test_text2img(
#     model_path="./models/rdm/rdm768x768/model.ckpt",
#     config_path="./models/rdm/rdm768x768/config.yaml",
#     prompt="a happy bear reading a newspaper, oil on canvas",
#     n_samples=3,  # CUDA 可以轻松生成多个样本
#     ddim_steps=50,  # 更多步数，更高质量
#     scale=7.5,
#     plms=True,
#     skip_grid=False,
#     H=768, W=768  # 原始高清尺寸
# )

model = get_model(
    model_path="./models/rdm/rdm768x768/model.ckpt",
    config_path="./models/rdm/rdm768x768/config.yaml"
)
print(model)
# Out:
# c:\Users\Alvis\OneDrive - Office365\PaperReading\computer_vision\diffusion_models\21_StableDiffusion1.5\labs\models\rdm\latent_diffusion\scripts\knn2img.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues relat
# ...

# %% [markdown]
# ```python
# LatentDiffusion(
#   (model): DiffusionWrapper(
#     (diffusion_model): UNetModel(
#       (time_embed): Sequential(
#         (0): Linear(in_features=448, out_features=1792, bias=True)
#         (1): SiLU()
#         (2): Linear(in_features=1792, out_features=1792, bias=True)
#       )
#       (input_blocks): ModuleList(
#         (0): TimestepEmbedSequential(
#           (0): Conv2d(16, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1-2): 2 x TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 448, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=448, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 448, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Identity()
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 448, eps=1e-06, affine=True)
#             (proj_in): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=448, out_features=448, bias=False)
#                   (to_k): Linear(in_features=448, out_features=448, bias=False)
#                   (to_v): Linear(in_features=448, out_features=448, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=448, out_features=448, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=448, out_features=3584, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=1792, out_features=448, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=448, out_features=448, bias=False)
#                   (to_k): Linear(in_features=768, out_features=448, bias=False)
#                   (to_v): Linear(in_features=768, out_features=448, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=448, out_features=448, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (3): TimestepEmbedSequential(
#           (0): Downsample(
#             (op): Conv2d(448, 448, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           )
#         )
#         (4): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 448, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(448, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=896, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(448, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 896, eps=1e-06, affine=True)
#             (proj_in): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=896, out_features=896, bias=False)
#                   (to_v): Linear(in_features=896, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=896, out_features=7168, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=3584, out_features=896, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=768, out_features=896, bias=False)
#                   (to_v): Linear(in_features=768, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=896, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Identity()
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 896, eps=1e-06, affine=True)
#             (proj_in): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=896, out_features=896, bias=False)
#                   (to_v): Linear(in_features=896, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=896, out_features=7168, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=3584, out_features=896, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=768, out_features=896, bias=False)
#                   (to_v): Linear(in_features=768, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (6): TimestepEmbedSequential(
#           (0): Downsample(
#             (op): Conv2d(896, 896, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           )
#         )
#         (7): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(896, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1344, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(896, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 1344, eps=1e-06, affine=True)
#             (proj_in): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=1344, out_features=10752, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=5376, out_features=1344, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (8): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1344, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Identity()
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 1344, eps=1e-06, affine=True)
#             (proj_in): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=1344, out_features=10752, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=5376, out_features=1344, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (9): TimestepEmbedSequential(
#           (0): Downsample(
#             (op): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           )
#         )
#         (10): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(1344, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1792, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(1344, 1792, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (11): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1792, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Identity()
#           )
#         )
#       )
#       (middle_block): TimestepEmbedSequential(
#         (0): ResBlock(
#           (in_layers): Sequential(
#             (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (h_upd): Identity()
#           (x_upd): Identity()
#           (emb_layers): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=1792, out_features=1792, bias=True)
#           )
#           (out_layers): Sequential(
#             (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Dropout(p=0, inplace=False)
#             (3): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (skip_connection): Identity()
#         )
#         (1): SpatialTransformer(
#           (norm): GroupNorm(32, 1792, eps=1e-06, affine=True)
#           (proj_in): Conv2d(1792, 1792, kernel_size=(1, 1), stride=(1, 1))
#           (transformer_blocks): ModuleList(
#             (0): BasicTransformerBlock(
#               (attn1): CrossAttention(
#                 (to_q): Linear(in_features=1792, out_features=1792, bias=False)
#                 (to_k): Linear(in_features=1792, out_features=1792, bias=False)
#                 (to_v): Linear(in_features=1792, out_features=1792, bias=False)
#                 (to_out): Sequential(
#                   (0): Linear(in_features=1792, out_features=1792, bias=True)
#                   (1): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (ff): FeedForward(
#                 (net): Sequential(
#                   (0): GEGLU(
#                     (proj): Linear(in_features=1792, out_features=14336, bias=True)
#                   )
#                   (1): Dropout(p=0.0, inplace=False)
#                   (2): Linear(in_features=7168, out_features=1792, bias=True)
#                 )
#               )
#               (attn2): CrossAttention(
#                 (to_q): Linear(in_features=1792, out_features=1792, bias=False)
#                 (to_k): Linear(in_features=768, out_features=1792, bias=False)
#                 (to_v): Linear(in_features=768, out_features=1792, bias=False)
#                 (to_out): Sequential(
#                   (0): Linear(in_features=1792, out_features=1792, bias=True)
#                   (1): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (norm1): LayerNorm((1792,), eps=1e-05, elementwise_affine=True)
#               (norm2): LayerNorm((1792,), eps=1e-05, elementwise_affine=True)
#               (norm3): LayerNorm((1792,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (proj_out): Conv2d(1792, 1792, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResBlock(
#           (in_layers): Sequential(
#             (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (h_upd): Identity()
#           (x_upd): Identity()
#           (emb_layers): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=1792, out_features=1792, bias=True)
#           )
#           (out_layers): Sequential(
#             (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Dropout(p=0, inplace=False)
#             (3): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (skip_connection): Identity()
#         )
#       )
#       (output_blocks): ModuleList(
#         (0-1): 2 x TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 3584, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(3584, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1792, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(3584, 1792, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (2): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 3136, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(3136, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1792, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(3136, 1792, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Upsample(
#             (conv): Conv2d(1792, 1792, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (3): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 3136, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(3136, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1344, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(3136, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 1344, eps=1e-06, affine=True)
#             (proj_in): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=1344, out_features=10752, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=5376, out_features=1344, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (4): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 2688, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(2688, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1344, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(2688, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 1344, eps=1e-06, affine=True)
#             (proj_in): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=1344, out_features=10752, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=5376, out_features=1344, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (5): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 2240, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(2240, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=1344, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(2240, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 1344, eps=1e-06, affine=True)
#             (proj_in): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=1344, out_features=10752, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=5376, out_features=1344, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=1344, out_features=1344, bias=False)
#                   (to_k): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_v): Linear(in_features=768, out_features=1344, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=1344, out_features=1344, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((1344,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(1344, 1344, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Upsample(
#             (conv): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (6): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 2240, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(2240, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=896, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(2240, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 896, eps=1e-06, affine=True)
#             (proj_in): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=896, out_features=896, bias=False)
#                   (to_v): Linear(in_features=896, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=896, out_features=7168, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=3584, out_features=896, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=768, out_features=896, bias=False)
#                   (to_v): Linear(in_features=768, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (7): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 1792, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(1792, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=896, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(1792, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 896, eps=1e-06, affine=True)
#             (proj_in): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=896, out_features=896, bias=False)
#                   (to_v): Linear(in_features=896, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=896, out_features=7168, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=3584, out_features=896, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=768, out_features=896, bias=False)
#                   (to_v): Linear(in_features=768, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (8): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(1344, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=896, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(1344, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 896, eps=1e-06, affine=True)
#             (proj_in): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=896, out_features=896, bias=False)
#                   (to_v): Linear(in_features=896, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=896, out_features=7168, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=3584, out_features=896, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=896, out_features=896, bias=False)
#                   (to_k): Linear(in_features=768, out_features=896, bias=False)
#                   (to_v): Linear(in_features=768, out_features=896, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=896, out_features=896, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((896,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Upsample(
#             (conv): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (9): TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 1344, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(1344, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=448, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 448, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(1344, 448, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 448, eps=1e-06, affine=True)
#             (proj_in): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=448, out_features=448, bias=False)
#                   (to_k): Linear(in_features=448, out_features=448, bias=False)
#                   (to_v): Linear(in_features=448, out_features=448, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=448, out_features=448, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=448, out_features=3584, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=1792, out_features=448, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=448, out_features=448, bias=False)
#                   (to_k): Linear(in_features=768, out_features=448, bias=False)
#                   (to_v): Linear(in_features=768, out_features=448, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=448, out_features=448, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (10-11): 2 x TimestepEmbedSequential(
#           (0): ResBlock(
#             (in_layers): Sequential(
#               (0): GroupNorm32(32, 896, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Conv2d(896, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (h_upd): Identity()
#             (x_upd): Identity()
#             (emb_layers): Sequential(
#               (0): SiLU()
#               (1): Linear(in_features=1792, out_features=448, bias=True)
#             )
#             (out_layers): Sequential(
#               (0): GroupNorm32(32, 448, eps=1e-05, affine=True)
#               (1): SiLU()
#               (2): Dropout(p=0, inplace=False)
#               (3): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (skip_connection): Conv2d(896, 448, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): SpatialTransformer(
#             (norm): GroupNorm(32, 448, eps=1e-06, affine=True)
#             (proj_in): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1))
#             (transformer_blocks): ModuleList(
#               (0): BasicTransformerBlock(
#                 (attn1): CrossAttention(
#                   (to_q): Linear(in_features=448, out_features=448, bias=False)
#                   (to_k): Linear(in_features=448, out_features=448, bias=False)
#                   (to_v): Linear(in_features=448, out_features=448, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=448, out_features=448, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (ff): FeedForward(
#                   (net): Sequential(
#                     (0): GEGLU(
#                       (proj): Linear(in_features=448, out_features=3584, bias=True)
#                     )
#                     (1): Dropout(p=0.0, inplace=False)
#                     (2): Linear(in_features=1792, out_features=448, bias=True)
#                   )
#                 )
#                 (attn2): CrossAttention(
#                   (to_q): Linear(in_features=448, out_features=448, bias=False)
#                   (to_k): Linear(in_features=768, out_features=448, bias=False)
#                   (to_v): Linear(in_features=768, out_features=448, bias=False)
#                   (to_out): Sequential(
#                     (0): Linear(in_features=448, out_features=448, bias=True)
#                     (1): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (norm1): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#                 (norm2): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#                 (norm3): LayerNorm((448,), eps=1e-05, elementwise_affine=True)
#               )
#             )
#             (proj_out): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#       (out): Sequential(
#         (0): GroupNorm32(32, 448, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(448, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (model_ema): LitEma()
#   (first_stage_model): AutoencoderKL(
#     (encoder): Encoder(
#       (conv_in): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (down): ModuleList(
#         (0-1): 2 x Module(
#           (block): ModuleList(
#             (0-1): 2 x ResnetBlock(
#               (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#           (downsample): Downsample(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#         (2): Module(
#           (block): ModuleList(
#             (0): ResnetBlock(
#               (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (nin_shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (1): ResnetBlock(
#               (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#           (downsample): Downsample(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#         (3): Module(
#           (block): ModuleList(
#             (0-1): 2 x ResnetBlock(
#               (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#           (downsample): Downsample(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#         (4): Module(
#           (block): ModuleList(
#             (0): ResnetBlock(
#               (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (nin_shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (1): ResnetBlock(
#               (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList(
#             (0-1): 2 x AttnBlock(
#               (norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (q): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#               (k): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#               (v): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#               (proj_out): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#         )
#       )
#       (mid): Module(
#         (block_1): ResnetBlock(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (attn_1): AttnBlock(
#           (norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (q): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (k): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (v): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (proj_out): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (block_2): ResnetBlock(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (norm_out): GroupNorm(32, 512, eps=1e-06, affine=True)
#       (conv_out): Conv2d(512, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (decoder): Decoder(
#       (conv_in): Conv2d(16, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mid): Module(
#         (block_1): ResnetBlock(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (attn_1): AttnBlock(
#           (norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (q): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (k): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (v): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (proj_out): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (block_2): ResnetBlock(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (up): ModuleList(
#         (0): Module(
#           (block): ModuleList(
#             (0-2): 3 x ResnetBlock(
#               (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#         )
#         (1): Module(
#           (block): ModuleList(
#             (0): ResnetBlock(
#               (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (nin_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (1-2): 2 x ResnetBlock(
#               (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#           (upsample): Upsample(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (2): Module(
#           (block): ModuleList(
#             (0-2): 3 x ResnetBlock(
#               (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#           (upsample): Upsample(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (3): Module(
#           (block): ModuleList(
#             (0): ResnetBlock(
#               (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (nin_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (1-2): 2 x ResnetBlock(
#               (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList()
#           (upsample): Upsample(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (4): Module(
#           (block): ModuleList(
#             (0-2): 3 x ResnetBlock(
#               (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (attn): ModuleList(
#             (0-2): 3 x AttnBlock(
#               (norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (q): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#               (k): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#               (v): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#               (proj_out): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (upsample): Upsample(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (norm_out): GroupNorm(32, 128, eps=1e-06, affine=True)
#       (conv_out): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (loss): Identity()
#     (quant_conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#     (post_quant_conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (cond_stage_model): Identity()
# )
# ```

# %%
batch_size = 1  # 最小批量，避免显存占用
latent_channels = 16  # 对应原函数的 shape[0]
latent_h = 768 // 16  # 48
latent_w = 768 // 16  # 48
x_t = torch.randn(batch_size, latent_channels, latent_h, latent_w)  # 含噪 latent 输入
t = torch.randint(0, 1000, (batch_size,), dtype=torch.long)
clip_embed_dim = 768  # ViT-L/14 的文本编码维度（默认）
knn_embed_dim = 768  # 邻居特征维度（原函数默认，若未启用则设为 0）
use_neighbors = False  # 与原函数一致，默认不启用
if use_neighbors:
    c_dim = clip_embed_dim + knn_embed_dim
else:
    c_dim = clip_embed_dim
c = torch.randn(batch_size, c_dim)  # 条件输入（文本编码）
uc = torch.randn(batch_size, c_dim)  # 无条件引导输入（scale≠1 时需要）
summary(
    model,
    input_data=[x_t, c, t],
    uncond = uc,
    col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
    col_width=20,
    row_settings=["var_names", "depth"],
    device="cpu",
    verbose=1,
    depth=5
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\ldm\lib\site-packages\torchinfo\torchinfo.py:295, in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     294 if isinstance(x, (list, tuple)):
# --> 295     _ = model(*x, **kwargs)
#     296 elif isinstance(x, dict):
#
# File c:\ProgramData\miniconda3\envs\ldm\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniconda3\envs\ldm\lib\site-packages\torch\nn\modules\module.py:1603, in Module._call_impl(self, *args, **kwargs)
#    1601     args = bw_hook.setup_input_hook(args)
# -> 1603 result = forward_call(*args, **kwargs)
#    1604 if _global_forward_hooks or self._forward_hooks:
#
# ...
